# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
file = "avg_rain_state.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file)
df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x = np.arange(len(df))
tick_locations = x

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x, df['Inches'])
plt.xticks(tick_locations, df['State'], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1e04d8e9390>,
#   <matplotlib.axis.XTick at 0x1e04d8d08d0>,
#   <matplotlib.axis.XTick at 0x1e04d8d0fd0>,
#   <matplotlib.axis.XTick at 0x1e04e1feef0>,
#   <matplotlib.axis.XTick at 0x1e04e207400>,
#   <matplotlib.axis.XTick at 0x1e04e2078d0>,
#   <matplotlib.axis.XTick at 0x1e04e207b00>,
#   <matplotlib.axis.XTick at 0x1e04e207d30>,
#   <matplotlib.axis.XTick at 0x1e04e2104e0>,
#   <matplotlib.axis.XTick at 0x1e04e2109b0>,
#   <matplotlib.axis.XTick at 0x1e04e210e80>,
#   <matplotlib.axis.XTick at 0x1e04e217390>,
#   <matplotlib.axis.XTick at 0x1e04e217860>,
#   <matplotlib.axis.XTick at 0x1e04e217d30>,
#   <matplotlib.axis.XTick at 0x1e04e220240>,
#   <matplotlib.axis.XTick at 0x1e04e217908>,
#   <matplotlib.axis.XTick at 0x1e04e2105c0>,
#   <matplotlib.axis.XTick at 0x1e04e220198>,
#   <matplotlib.axis.XTick at 0x1e04e2209b0>,
#   <matplotlib.axis.XTick at 0x1e04e220e80>,
#   <matplotlib.axis.XTick at 0x1e04e227390>,
#   <matplotlib.axis.XTick at 0x1e04e227860>,
#   <matplotlib.axis.XTick at 0x1e04e227d30>,
#   <matplotlib.axis.XTick at 0x1e04e231240>,
#   <matplotlib.axis.XTick at 0x1e04e2274e0>,
#   <matplotlib.axis.XTick at 0x1e04e220a90>,
#   <matplotlib.axis.XTick at 0x1e04e2315f8>,
#   <matplotlib.axis.XTick at 0x1e04e231c50>,
#   <matplotlib.axis.XTick at 0x1e04e237208>,
#   <matplotlib.axis.XTick at 0x1e04e237780>,
#   <matplotlib.axis.XTick at 0x1e04e237cf8>,
#   <matplotlib.axis.XTick at 0x1e04e2402b0>,
#   <matplotlib.axis.XTick at 0x1e04e240828>,
#   <matplotlib.axis.XTick at 0x1e04e240da0>,
#   <matplotlib.axis.XTick at 0x1e04e240908>,
#   <matplotlib.axis.XTick at 0x1e04e231d30>,
#   <matplotlib.axis.XTick at 0x1e04e246278>,
#   <matplotlib.axis.XTick at 0x1e04e2467f0>,
#   <matplotlib.axis.XTick at 0x1e04e246d68>,
#   <matplotlib.axis.XTick at 0x1e04e24f320>,
#   <matplotlib.axis.XTick at 0x1e04e24f898>,
#   <matplotlib.axis.XTick at 0x1e04e24fe10>,
#   <matplotlib.axis.XTick at 0x1e04e2543c8>,
#   <matplotlib.axis.XTick at 0x1e04e24f3c8>,
#   <matplotlib.axis.XTick at 0x1e04e246d30>,
#   <matplotlib.axis.XTick at 0x1e04e220b00>,
#   <matplotlib.axis.XTick at 0x1e04e254320>,
#   <matplotlib.axis.XTick at 0x1e04e25c0f0>,
#   <matplotlib.axis.XTick at 0x1e04e25c5f8>,
#   <matplotlib.axis.XTick at 0x1e04e25cb70>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x))
plt.ylim(0, 65)
# Out:
# (0, 65)

# %%
# Set a Title and labels
plt.title("Avg Rain Per State")
plt.xlabel("States")
plt.ylabel("Rain (Inches)")
# Out:
# Text(339.12847222222223, 0.5, 'Rain (Inches)')

# %%
# Save our graph and show the graph
plt.savefig('avg_state_rain.png')
plt.tight_layout()
plt.show()
